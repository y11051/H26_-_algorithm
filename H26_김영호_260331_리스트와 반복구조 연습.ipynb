# %%
# 1. getIndex(num_list, target)
def getIndex(num_list, target):
    target = int(target)
    for i in range(len(num_list)):
        if num_list[i] == target:
            return i
    return -1

test_list = [23]
    
# 2. getMax(num_list)
def getMax(num_list):
    max_val = num_list[0]
    for num in num_list:
        if num > max_val:
            max_val = num
    return max_val

# 3. getMin(num_list)
def getMin(num_list):
    min_val = num_list[0]
    for num in num_list:
        if num < min_val:
            min_val = num
    return min_val

# 4. countGT(num_list, target)
def countGT(num_list, target):
    count = 0
    for num in num_list:
        if num > target:
            count = count + 1
    return count

# 5. sumList(num_list)
def sumList(num_list): 
    total = 0
    for num in num_list:
        total = total + num
    return total

# 6. swapList(num_List)
def swapList(num_list):
    n = len(num_list)
    for i in range(n // 2):
        temp = num_list[i]
        num_list[i] = num_list[n - 1 - i]
        num_list[n - 1 - i] = temp

number_list = [23, 45, 27, 11, 25, 65, 78]
print(getIndex(number_list, 25))
print(getMax(number_list))
print(getMin(number_list))
print(countGT(number_list, 42))
print(sumList(number_list))
swapList(number_list)
print(number_list)
# Out:
# 4
# 78
# 11
# 3
# 274
# [78, 65, 25, 11, 27, 45, 23]
